# %%
import bokeh
from bokeh.document import Document
from bokeh.plotting import figure
from bokeh.io import show, output_notebook,curdoc
import json
output_notebook()

with open('document.json') as f:
    d = f.read()

D = Document().from_json_string(d)

curdoc().clear()
f = D.roots[0]
D.clear()

show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#     <p style="background-color: #f2d7dc;">Warning: Requesting CDN BokehJS version '2.0.0dev6' from Bokeh development version '2.0.0dev6-26-gfe9fca8f3'. This configuration is unsupported and may not work!</p>
#   <div class="bk-root" id="70ebb854-b5b2-4b69-8224-4df8115dd96a" data-root-id="1002"></div>
