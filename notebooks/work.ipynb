# %%
# %load mtplot.py
import pandas as pd
from bokeh.plotting import figure
from bokeh.io import output_notebook,show
from bokeh.models import ColumnDataSource
from bokeh.layouts import gridplot
from bokeh.models import WheelZoomTool,DataRange1d, BoxAnnotation, ResetTool
from io import StringIO

_annotation_file=StringIO('''MT	ensembl	tRNA	577	647	.	+	.	ID=transcript:ENST00000387314;Parent=gene:ENSG00000210049;Name=MT-TF-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387314;transcript_support_level=NA;version=1
MT	ensembl	rRNA	648	1601	.	+	.	ID=transcript:ENST00000389680;Parent=gene:ENSG00000211459;Name=MT-RNR1-201;biotype=Mt_rRNA;tag=basic;transcript_id=ENST00000389680;transcript_support_level=NA;version=2
MT	ensembl	tRNA	1602	1670	.	+	.	ID=transcript:ENST00000387342;Parent=gene:ENSG00000210077;Name=MT-TV-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387342;transcript_support_level=NA;version=1
MT	ensembl	rRNA	1671	3229	.	+	.	ID=transcript:ENST00000387347;Parent=gene:ENSG00000210082;Name=MT-RNR2-201;biotype=Mt_rRNA;tag=basic;transcript_id=ENST00000387347;transcript_support_level=NA;version=2
MT	ensembl	tRNA	3230	3304	.	+	.	ID=transcript:ENST00000386347;Parent=gene:ENSG00000209082;Name=MT-TL1-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000386347;transcript_support_level=NA;version=1
MT	ensembl	mRNA	3307	4262	.	+	.	ID=transcript:ENST00000361390;Parent=gene:ENSG00000198888;Name=MT-ND1-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361390;transcript_support_level=NA;version=2
MT	ensembl	tRNA	4263	4331	.	+	.	ID=transcript:ENST00000387365;Parent=gene:ENSG00000210100;Name=MT-TI-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387365;transcript_support_level=NA;version=1
MT	ensembl	tRNA	4329	4400	.	-	.	ID=transcript:ENST00000387372;Parent=gene:ENSG00000210107;Name=MT-TQ-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387372;transcript_support_level=NA;version=1
MT	ensembl	tRNA	4402	4469	.	+	.	ID=transcript:ENST00000387377;Parent=gene:ENSG00000210112;Name=MT-TM-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387377;transcript_support_level=NA;version=1
MT	ensembl	mRNA	4470	5511	.	+	.	ID=transcript:ENST00000361453;Parent=gene:ENSG00000198763;Name=MT-ND2-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361453;transcript_support_level=NA;version=3
MT	ensembl	tRNA	5512	5579	.	+	.	ID=transcript:ENST00000387382;Parent=gene:ENSG00000210117;Name=MT-TW-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387382;transcript_support_level=NA;version=1
MT	ensembl	tRNA	5587	5655	.	-	.	ID=transcript:ENST00000387392;Parent=gene:ENSG00000210127;Name=MT-TA-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387392;transcript_support_level=NA;version=1
MT	ensembl	tRNA	5657	5729	.	-	.	ID=transcript:ENST00000387400;Parent=gene:ENSG00000210135;Name=MT-TN-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387400;transcript_support_level=NA;version=1
MT	ensembl	tRNA	5761	5826	.	-	.	ID=transcript:ENST00000387405;Parent=gene:ENSG00000210140;Name=MT-TC-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387405;transcript_support_level=NA;version=1
MT	ensembl	tRNA	5826	5891	.	-	.	ID=transcript:ENST00000387409;Parent=gene:ENSG00000210144;Name=MT-TY-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387409;transcript_support_level=NA;version=1
MT	ensembl	mRNA	5904	7445	.	+	.	ID=transcript:ENST00000361624;Parent=gene:ENSG00000198804;Name=MT-CO1-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361624;transcript_support_level=NA;version=2
MT	ensembl	tRNA	7446	7514	.	-	.	ID=transcript:ENST00000387416;Parent=gene:ENSG00000210151;Name=MT-TS1-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387416;transcript_support_level=NA;version=2
MT	ensembl	tRNA	7518	7585	.	+	.	ID=transcript:ENST00000387419;Parent=gene:ENSG00000210154;Name=MT-TD-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387419;transcript_support_level=NA;version=1
MT	ensembl	mRNA	7586	8269	.	+	.	ID=transcript:ENST00000361739;Parent=gene:ENSG00000198712;Name=MT-CO2-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361739;transcript_support_level=NA;version=1
MT	ensembl	tRNA	8295	8364	.	+	.	ID=transcript:ENST00000387421;Parent=gene:ENSG00000210156;Name=MT-TK-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387421;transcript_support_level=NA;version=1
MT	ensembl	mRNA	8366	8572	.	+	.	ID=transcript:ENST00000361851;Parent=gene:ENSG00000228253;Name=MT-ATP8-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361851;transcript_support_level=NA;version=1
MT	ensembl	mRNA	8527	9207	.	+	.	ID=transcript:ENST00000361899;Parent=gene:ENSG00000198899;Name=MT-ATP6-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361899;transcript_support_level=NA;version=2
MT	ensembl	mRNA	9207	9990	.	+	.	ID=transcript:ENST00000362079;Parent=gene:ENSG00000198938;Name=MT-CO3-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000362079;transcript_support_level=NA;version=2
MT	ensembl	tRNA	9991	10058	.	+	.	ID=transcript:ENST00000387429;Parent=gene:ENSG00000210164;Name=MT-TG-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387429;transcript_support_level=NA;version=1
MT	ensembl	mRNA	10059	10404	.	+	.	ID=transcript:ENST00000361227;Parent=gene:ENSG00000198840;Name=MT-ND3-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361227;transcript_support_level=NA;version=2
MT	ensembl	tRNA	10405	10469	.	+	.	ID=transcript:ENST00000387439;Parent=gene:ENSG00000210174;Name=MT-TR-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387439;transcript_support_level=NA;version=1
MT	ensembl	mRNA	10470	10766	.	+	.	ID=transcript:ENST00000361335;Parent=gene:ENSG00000212907;Name=MT-ND4L-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361335;transcript_support_level=NA;version=1
MT	ensembl	mRNA	10760	12137	.	+	.	ID=transcript:ENST00000361381;Parent=gene:ENSG00000198886;Name=MT-ND4-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361381;transcript_support_level=NA;version=2
MT	ensembl	tRNA	12138	12206	.	+	.	ID=transcript:ENST00000387441;Parent=gene:ENSG00000210176;Name=MT-TH-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387441;transcript_support_level=NA;version=1
MT	ensembl	tRNA	12207	12265	.	+	.	ID=transcript:ENST00000387449;Parent=gene:ENSG00000210184;Name=MT-TS2-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387449;transcript_support_level=NA;version=1
MT	ensembl	tRNA	12266	12336	.	+	.	ID=transcript:ENST00000387456;Parent=gene:ENSG00000210191;Name=MT-TL2-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387456;transcript_support_level=NA;version=1
MT	ensembl	mRNA	12337	14148	.	+	.	ID=transcript:ENST00000361567;Parent=gene:ENSG00000198786;Name=MT-ND5-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361567;transcript_support_level=NA;version=2
MT	ensembl	mRNA	14149	14673	.	-	.	ID=transcript:ENST00000361681;Parent=gene:ENSG00000198695;Name=MT-ND6-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361681;transcript_support_level=NA;version=2
MT	ensembl	tRNA	14674	14742	.	-	.	ID=transcript:ENST00000387459;Parent=gene:ENSG00000210194;Name=MT-TE-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387459;transcript_support_level=NA;version=1
MT	ensembl	mRNA	14747	15887	.	+	.	ID=transcript:ENST00000361789;Parent=gene:ENSG00000198727;Name=MT-CYB-201;biotype=protein_coding;tag=basic;transcript_id=ENST00000361789;transcript_support_level=NA;version=2
MT	ensembl	tRNA	15888	15953	.	+	.	ID=transcript:ENST00000387460;Parent=gene:ENSG00000210195;Name=MT-TT-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387460;transcript_support_level=NA;version=2
MT	ensembl	tRNA	15956	16023	.	-	.	ID=transcript:ENST00000387461;Parent=gene:ENSG00000210196;Name=MT-TP-201;biotype=Mt_tRNA;tag=basic;transcript_id=ENST00000387461;transcript_support_level=NA;version=2
''')

_annotation = pd.read_csv(_annotation_file,sep='\t',header=None,names=['contig','ref','type','start','end','NA1','strand','NA2','keys'])
_annotation['name'] = _annotation['keys'].apply(lambda x:x.split(';')[2].split('=')[1])
_annotation=_annotation.drop(['contig','ref','NA1','NA2','keys'],axis=1)

output_notebook()


def mitoplot(y,title=None,color='blue'):
    '''Show data indexed by mitochondrial position on annotated plot. Positions are 0-based.
    Data should be an array of length 16569.  Blue is mRNA, pink is tRNA, gray is rRNA, white is
    non-coding regions of the mitochondrial genome -- reference RCRS.'''
    options = dict(plot_width=1000, plot_height=300,
                   tools="xpan,xwheel_zoom,reset",x_range=DataRange1d(bounds='auto',range_padding=0))
    colordict={'tRNA':'pink','mRNA':'lightblue','rRNA':'lightgray'}
    p1 = figure(title=title,**options)
    p1.line(list(range(16569)),y,color=color)
    for index, row in _annotation.iterrows():
        box=BoxAnnotation(left=row['start']-1.2,right=row['end']-1+.2,fill_color=colordict[row['type']])
        p1.add_layout(box)
    return p1
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

# %%
y=[np.sin(x/1000) for x in range(16569)]

# %%
p=mitoplot(y)

# %%
show(p)
# Out:
#   <div class="bk-root" id="ff06e593-4945-4ebc-88e7-b58ed096040e" data-root-id="65628"></div>

# %%
from pprint import pprint

# %%
def dump(obj):
  for attr in dir(obj):
    print("obj.%s = %r" % (attr, getattr(obj, attr)))

# %%
dump(p.xaxis[0])
# Out:
# obj.__cached_all__overridden_defaults__ = {'ticker': <function LinearAxis.<lambda> at 0x7f0cdc9cabf8>, 'formatter': <function LinearAxis.<lambda> at 0x7f0cdc9cac80>, 'axis_label_text_font_size': {'value': '10pt'}, 'axis_label_text_font_style': 'italic', 'major_label_text_align': 'center', 'major_label_text_baseline': 'alphabetic', 'major_label_text_font_size': {'value': '8pt'}, 'level': 'overlay'}
# ...

# %%
from bokeh.layouts import column, row
from bokeh.models import LabelSet, Label, Range1d
p2 = figure(plot_height=50,plot_width=1000)
p2.xaxis.visible=False
p2.yaxis.visible=False
p2.xgrid.visible=False
p2.ygrid.visible=False
p2.background_fill_color='beige'

p2.outline_line_width=0
p2.toolbar.logo=None
p2.toolbar_location = None

label1 = Label(x=1.1,y=.25,text='mRNA')
label2 = Label(x=3.1,y=.25,text='tRNA')
label3 = Label(x=5.1, y=.25, text='rRNA')
p2.add_layout(label1)
p2.add_layout(label2)
p2.add_layout(label3)

p2.quad(top=[1,1,1,1],bottom=[0,0,0,0],left=[1,3,5,8],right=[1.5,3.5,5.5,8.5],color=['lightblue','pink','lightgray','beige'])
show(column(p,p2))
# Out:
#   <div class="bk-root" id="fe656b0d-4084-40a2-99b6-826a96c05ca8" data-root-id="26488"></div>

# %%
p=figure(plot_width=1000,plot_height=100)
source=ColumnDataSource(F)

# %%
p.vbar(x='X',top='Y',width=0.5,source=source,color='color',legend='name')
p.xaxis.visible=False
p.yaxis.visible=False
p.xgrid.visible=False
p.ygrid.visible=False
p.toolbar.logo=None
p.toolbar_location=None
p.legend.orientation='horizontal'
p.legend.location=(10,10)
x=p.select('legend')

# %%
show(p)
# Out:
#   <div class="bk-root" id="713048fc-a74e-4073-9bb2-78f6626907b6" data-root-id="64587"></div>

# %%
from bokeh.palettes import Spectral3
X=[0,1,2,3]
Y=[1,1,1,1]
names=['mRNA','tRNA','rRNA','mRNA']
color=['lightblue','pink','lightgray','lightblue']
F=pd.DataFrame([X,Y,names,color],index=['X','Y','name','color']).transpose()

# %%
F
# Out:
#    X  Y  name      color
# 0  0  1  mRNA  lightblue
# 1  1  1  tRNA       pink
# 2  2  1  rRNA  lightgray
# 3  3  1  mRNA  lightblue

# %%
x
# Out:
# []

# %%
_annotation
# Out:
#     type  start    end strand         name
# 0   tRNA    577    647      +    MT-TF-201
# 1   rRNA    648   1601      +  MT-RNR1-201
# 2   tRNA   1602   1670      +    MT-TV-201
# 3   rRNA   1671   3229      +  MT-RNR2-201
# 4   tRNA   3230   3304      +   MT-TL1-201
# 5   mRNA   3307   4262      +   MT-ND1-201
# 6   tRNA   4263   4331      +    MT-TI-201
# 7   tRNA   4329   4400      -    MT-TQ-201
# 8   tRNA   4402   4469      +    MT-TM-201
# 9   mRNA   4470   5511      +   MT-ND2-201
# 10  tRNA   5512   5579      +    MT-TW-201
# 11  tRNA   5587   5655      -    MT-TA-201
# 12  tRNA   5657   5729      -    MT-TN-201
# 13  tRNA   5761   5826      -    MT-TC-201
# 14  tRNA   5826   5891      -    MT-TY-201
# 15  mRNA   5904   7445      +   MT-CO1-201
# 16  tRNA   7446   7514      -   MT-TS1-201
# 17  tRNA   7518   7585      +    MT-TD-201
# 18  mRNA   7586   8269      +   MT-CO2-201
# 19  tRNA   8295   8364      +    MT-TK-201
# 20  mRNA   8366   8572      +  MT-ATP8-201
# ...

# %%
_annotation['length']=_annotation['end']-_annotation['start']+1

# %%
A=ColumnDataSource(_annotation)

# %%
p=figure(plot_width=1000,plot_height=300)

# %%
p.quad(left='start',right='end',bottom=0,top=1,source=A,color='color',legend='type')
# Out:
# GlyphRenderer(id='69841', ...)

# %%
_annotation['color']=_annotation['type'].map({'mRNA':'lightblue','tRNA':'pink','rRNA':'lightgray'})

# %%
show(p)
# Out:
#   <div class="bk-root" id="5dbb375a-8647-4299-a5c6-177f679caa19" data-root-id="68791"></div>

# %%
from bokeh.models import Legend, LegendItem


def mitoplot(y,title=None,color='blue'):
    '''Show data indexed by mitochondrial position on annotated plot. Positions are 0-based.
    Data should be an array of length 16569.  Blue is mRNA, pink is tRNA, gray is rRNA, white is
    non-coding regions of the mitochondrial genome -- reference RCRS.'''
    
    figure_options = dict(plot_width=1000, plot_height=300,
                   tools="xpan,xwheel_zoom,reset",background_fill_color='beige',
                   x_range=DataRange1d(bounds='auto',range_padding=0),
                   y_range=DataRange1d(range_padding=0),
                   toolbar_location='right')
    

    
    p1 = figure(title=title,**figure_options)
    
    quads={}
    legend_items=[]
    
    M=1.4*np.max(y)
    for x in ['mRNA','tRNA','rRNA']:
        A = ColumnDataSource(_annotation[_annotation['type']==x])
        quads[x] = p1.quad(left='start',right='end',bottom=0,top=M,source=A, color='color') 
        legend_items.append((x,[quads[x]]))
        
    dloop=p1.quad(left=0,right=0,bottom=-.2,top=M,color='beige')
    legend_items.append(('ctrl',[dloop]))
    
    legend_attrs = { 'orientation': 'horizontal', 'margin': 2,'padding':2,'spacing':5,'glyph_width':10,'label_text_font_size':'8pt'}
    legend = Legend(items=legend_items,**legend_attrs)
    
    p1.line(list(range(16569)),y,color=color)
    
    p1.xgrid.visible=False
    p1.ygrid.visible=False
    
    p1.add_layout(legend,'center')
      
    return p1

# %%
y=np.abs(np.random.normal(0,20,16569))

# %%
p=mitoplot(y,title='Experimental',color='green')

# %%
show(p)
# Out:
#   <div class="bk-root" id="27585d90-d512-417b-9c78-3c88e94bc5bf" data-root-id="192442"></div>
