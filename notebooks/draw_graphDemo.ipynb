# %%
from bokeh.plotting import figure, Figure
from bokeh.models import MultiLine, Toolbar
from bokeh.models import GraphRenderer
from bokeh.io import output_notebook, show
from utils.graph import draw_model
import numpy as np
from numpy.random import normal
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="242450">Loading BokehJS ...</span>
#     </div>

# %%
x=np.linspace(-10,10,100)
y0=np.sin(x)
y=y0+normal(0,.1,size=x.shape[0])
f = figure(width=500,height=500,title='Sin wave with noise')
D = ColumnDataSource({'x':x,'y':y,'y0':y0})
f.line(x='x',y='y0',source=D)
f.scatter(x='x',y='y',source=D)

# %%
show(f)
# Out:
#   <div class="bk-root" id="b8248d91-d013-44e1-a3e4-a3cc1f82617d" data-root-id="243665"></div>

# %%
show(draw_model(f))
# Out:
#   <div class="bk-root" id="4c0e3b63-019e-43b3-8a16-2e8250b23f05" data-root-id="253081"></div>
